# %% [markdown]
# # Using Folium to generate maps to visualize various datasets in New York City, NY, Austin, TX and Chicago, IL

# %%
# INSTALL LIBRARIES

import pandas as pd
import numpy as np
import folium

# %%
# define the world map
world_map = folium.Map()

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_8626105605e9419f87358bde9af11aed%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8626105605e9419f87358bde9af11aed%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_8626105605e9419f87358bde9af11aed%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_8626105605e9419f87358bde9af11aed%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %% [markdown]
# ## New York City Dataset

# %% [markdown]
# ### New York City Dataset found at https://data.cityofnewyork.us/Health/DOHMH-New-York-City-Restaurant-Inspection-Results/43nn-pn8j

# %% [markdown]
# ## Visualizing Restaurant Citations in New York City, NY

# %%
# Import the dataset for New York City, NY
# Note: For the purposes of this project in order to visualize the map, rows where the latitude and longitude values were NaN or 0
# were deleted

df_new_york_citations = pd.read_csv(r'C:\Users\jksmi\Downloads\Folium Project\DOHMH_New_York_City_Restaurant_Inspection_Results_clean.csv')
df_new_york_citations
# Out:
#            CAMIS                                DBA           BORO BUILDING  \
# 0       41224985               BENJAMIN STEAK HOUSE      Manhattan       52
# 1       50080154                  RICHMOND REPUBLIC  Staten Island     4459
# 2       50068816              BROOKLYN PIZZA MARKET       Brooklyn      267
# 3       50013915                       VANILLA CAFE         Queens     9918
# 4       41205309  JOE G RESTAURANT (DA VINCI HOTEL)      Manhattan      244
# ...          ...                                ...            ...      ...
# 376635  50066796                  ONE STATION PLAZA         Queens    21310
# 376636  50088958                     GOPCHANG STORY         Queens    16018
# 376637  50088958                     GOPCHANG STORY         Queens    16018
# 376638  50088958                     GOPCHANG STORY         Queens    16018
# 376639  41321647           PARK AVENUE LUNCHEONETTE       Brooklyn      131
#
#                   STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 0       EAST   41 STREET    10017  2122979177          Steakhouse
# 1             AMBOY ROAD    10312  3473302480            American
# 2           SMITH STREET    11231  9176973215               Pizza
# 3               37TH AVE    11368  7185051480             Spanish
# 4       WEST   56 STREET    10019  2127653160             Italian
# ...                  ...      ...         ...                 ...
# 376635          41ST AVE    11361  7182240060            American
# 376636     NORTHERN BLVD    11358  7186873001              Korean
# 376637     NORTHERN BLVD    11358  7186873001              Korean
# 376638     NORTHERN BLVD    11358  7186873001              Korean
# 376639       PARK AVENUE    11205  7186436434      Latin American
#
#        INSPECTION DATE                                           ACTION  \
# 0            1/31/2020  Violations were cited in the following area(s).
# 1           10/18/2018  Violations were cited in the following area(s).
# 2            12/8/2018  Violations were cited in the following area(s).
# 3            1/10/2019  Violations were cited in the following area(s).
# 4            8/17/2018  Violations were cited in the following area(s).
# ...                ...                                              ...
# 376635      12/19/2019  Violations were cited in the following area(s).
# 376636      10/28/2019  Violations were cited in the following area(s).
# 376637      10/28/2019  Violations were cited in the following area(s).
# 376638      10/28/2019  Violations were cited in the following area(s).
# 376639        8/1/2017  Violations were cited in the following area(s).
#
#        VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 0                 04N  Filth flies or food/refuse/sewage-associated (...
# 1                 06D  Food contact surface not properly washed, rins...
# 2                 08B  Covered garbage receptacle not provided or ina...
# 3                 09C      Food contact surface not properly maintained.
# 4                 04M  Live roaches present in facility's food and/or...
# ...               ...                                                ...
# 376635            04L  Evidence of mice or live mice present in facil...
# 376636            06C  Food not protected from potential source of co...
# 376637            06C  Food not protected from potential source of co...
# 376638            06C  Food not protected from potential source of co...
# 376639            06D  Food contact surface not properly washed, rins...
#
#        CRITICAL FLAG  SCORE GRADE GRADE DATE RECORD DATE  \
# 0           Critical   13.0     A  1/31/2020   10/8/2021
# 1           Critical   22.0   NaN        NaN   10/8/2021
# 2       Not Critical   13.0     A  12/8/2018   10/8/2021
# 3       Not Critical    9.0     A  1/10/2019   10/8/2021
# 4           Critical   21.0   NaN        NaN   10/8/2021
# ...              ...    ...   ...        ...         ...
# 376635      Critical    9.0   NaN        NaN   10/8/2021
# 376636      Critical   24.0   NaN        NaN   10/8/2021
# 376637      Critical   24.0   NaN        NaN   10/8/2021
# 376638      Critical   24.0   NaN        NaN   10/8/2021
# 376639      Critical   43.0   NaN        NaN   10/8/2021
#
#                                       INSPECTION TYPE   Latitude  Longitude
# 0               Cycle Inspection / Initial Inspection  40.751886 -73.979214
# 1       Pre-permit (Operational) / Initial Inspection  40.544380 -74.162347
# 2               Cycle Inspection / Initial Inspection  40.682755 -73.993139
# 3               Cycle Inspection / Initial Inspection  40.752317 -73.867939
# 4               Cycle Inspection / Initial Inspection  40.765659 -73.982499
# ...                                               ...        ...        ...
# 376635          Cycle Inspection / Initial Inspection  40.763515 -73.771705
# 376636          Cycle Inspection / Initial Inspection  40.762792 -73.805280
# 376637          Cycle Inspection / Initial Inspection  40.762792 -73.805280
# 376638          Cycle Inspection / Initial Inspection  40.762792 -73.805280
# 376639          Cycle Inspection / Initial Inspection  40.696270 -73.974305
#
# [376640 rows x 20 columns]

# %%
# Due to the large size of the dataset (376640 rows) I will reduce the dataframe to 100 citations
# Pulling only the 1st 100 crimes in the df_new_york_citations dataframe

limit = 100
df_new_york_citations = df_new_york_citations.iloc[0:limit, :]

# %%
# Confirm that dataframe has been reduced

df_new_york_citations.shape
# Out:
# (100, 20)

# %%
# Listing the columns in the dataframe

df_new_york_citations.columns.tolist()
# Out:
# ['CAMIS',
#  'DBA',
#  'BORO',
#  'BUILDING',
#  'STREET',
#  'ZIPCODE',
#  'PHONE',
#  'CUISINE DESCRIPTION',
#  'INSPECTION DATE',
#  'ACTION',
#  'VIOLATION CODE',
#  'VIOLATION DESCRIPTION',
#  'CRITICAL FLAG',
#  'SCORE',
#  'GRADE',
#  'GRADE DATE',
#  'RECORD DATE',
#  'INSPECTION TYPE',
#  'Latitude',
#  'Longitude']

# %%
# Now to update the column names in the dataset to make working with the dataset easier

new_column_list = ('id_number', 'restaurant_name', 'borough', 'building_number', 'street_name', 'zipcode', 'phone', 'cuisine_description', 'inspection_date', 'action', 'violation_code', 'violation_description', 'critical_flag', 'score', 'grade', 'grade_date', 'record_date', 'inspection_date', 'latitude', 'longitude')
df_new_york_citations.columns = new_column_list

# %%
# Now to check to see if new column names were updated in the dataframe

df_new_york_citations.columns.tolist()
# Out:
# ['id_number',
#  'restaurant_name',
#  'borough',
#  'building_number',
#  'street_name',
#  'zipcode',
#  'phone',
#  'cuisine_description',
#  'inspection_date',
#  'action',
#  'violation_code',
#  'violation_description',
#  'critical_flag',
#  'score',
#  'grade',
#  'grade_date',
#  'record_date',
#  'inspection_date',
#  'latitude',
#  'longitude']

# %%
# Now to visualize the New York City data
# New York City latitude and longitude values

nyc_latitude = 40.71
nyc_longitude = -74.00

# %%
nyc_map = folium.Map(location=[nyc_latitude, nyc_longitude], zoom_start=12)
nyc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b06ec0f2becd47c382cc78416387d335%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b06ec0f2becd47c382cc78416387d335%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b06ec0f2becd47c382cc78416387d335%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b06ec0f2becd47c382cc78416387d335%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.71%2C%20-74.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
# Add locations of the citations onto the map with markers that contain popup feature that labels 
# the violation_description

citation_locations = folium.map.FeatureGroup()

for lat, lng, in zip(df_new_york_citations.longitude, df_new_york_citations.latitude):
    citation_locations.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

latitudes = list(df_new_york_citations.latitude)
longitudes = list(df_new_york_citations.longitude)
labels = list(df_new_york_citations.violation_description)

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(nyc_map)
    
nyc_map.add_child(citation_locations)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_232f081dc5164144b9797343c6b9bf5c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_232f081dc5164144b9797343c6b9bf5c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %% [markdown]
# ## Now to try the Austin Dataset

# %% [markdown]
# ### Austin Dataset found at https://data.austintexas.gov/Public-Safety/2019-APD-Traffic-Fatality-Data/egpd-hqdi

# %% [markdown]
# ## Visualizing Traffic Fatalities in Austin, TX

# %%
# Import the dataset for Austin, TX traffic fatalities

df_austin_traffic = pd.read_csv(r'C:\Users\jksmi\Downloads\Folium Project - Crime Incident (SanFran and Chicago)\2019_APD_Traffic_Fatality_Data.csv')
df_austin_traffic
# Out:
#              Type  Fatal Crash Number  Number of Fatalities Case Number  \
# 0      Pedestrian                   1                     1  19-0150158
# 1   Motor Vehicle                   2                     1  19-0161105
# 2      Pedestrian                   3                     1  19-0081623
# 3      Pedestrian                   4                     1  19-0260086
# 4      Pedestrian                   5                     1  19-0320079
# ..            ...                 ...                   ...         ...
# 81     Pedestrian                  82                     1  19-3500150
# 82  Motor Vehicle                  83                     1  19-3510124
# 83     Pedestrian                  84                     1  19-3530313
# 84     Pedestrian                  85                     1  19-3560188
# 85     Pedestrian                  86                     1  19-3651208
#
#                                 Location Area              Date Month  Day  \
# 0                       10500 N IH 35 SB   ED   January 15 2019   Jan  Tue
# 1     W William Cannon Dr / Ridge Oak Rd   DA   January 16 2019   Jan  Wed
# 2   3600 Block S Capital of Texas HWY SB   DA   January 08 2019   Jan  Tue
# 3                        6900 N IH 35 SB   ID   January 26 2019   Jan  Sat
# 4             N IH 35 SVRD SB / E 6th St   GE  February 01 2019   Feb  Fri
# ..                                   ...  ...               ...   ...  ...
# 81                       6100 Cameron Rd   ID  December 16 2019   Dec  Mon
# 82          100 E Ben White Blvd SVRD EB   DA  December 17 2019   Dec  Tue
# 83                          7600 W SH 71   DA  December 19 2019   Dec  Thu
# 84                          11200 Dessau   ED  December 22 2019   Dec  Sun
# 85                            6729 Manor   CH  December 31 2019   Dec  Tue
#
#     Hour  ... Speeding Ran Red Light or Stop Sign DL Status incident  \
# 0      6  ...    False                      False                 ok
# 1     15  ...    False                       True                 ok
# 2     21  ...    False                      False              no dl
# 3      1  ...    False                      False                 ok
# 4      0  ...    False                      False                 ok
# ..   ...  ...      ...                        ...                ...
# 81     2  ...      NaN                      False                unk
# 82     4  ...     True                      False                 Ok
# 83     6  ...    False                      False            pending
# 84     2  ...    False                      False                 ok
# 85    18  ...    False                      False            pending
#
#    Suspected Impairment       Restraint type   Type of road  \
# 0                   ped                  NaN           IH35
# 1                  none       seatbelts worn   Local Street
# 2                  none                  NaN  Other Highway
# 3                   ped                  NaN           IH35
# 4                   ped  No helmet - scooter   Local Street
# ..                  ...                  ...            ...
# 81              unknown                  NaN   Local Street
# 82               driver       seatbelts worn  Other Highway
# 83                 none                  NaN  Other Highway
# 84                 none                  NaN  high use road
# 85                  ped                  NaN  high use road
#
#    Failure to stop and render aid    X coord    Y coord  Homeless
# 0                           False -97.681335  30.368955     False
# 1                           False -97.861421  30.228131     False
# 2                           False -97.801933  30.243596      True
# 3                           False -97.705467  30.330291      True
# 4                           False -97.735003  30.265881     False
# ..                            ...        ...        ...       ...
# 81                           True -97.697831  30.318902      True
# 82                          False -97.763598  30.223409     False
# 83                          False -97.880916  30.240668     False
# 84                          False -97.665833  30.372500     False
# 85                          False -97.666820  30.310396      True
#
# [86 rows x 23 columns]

# %%
# Listing the columns in the dataframe

df_austin_traffic.columns.tolist()
# Out:
# ['Type',
#  'Fatal Crash Number',
#  'Number of Fatalities',
#  'Case Number',
#  'Location',
#  'Area',
#  'Date',
#  'Month',
#  'Day',
#  'Hour',
#  'Time',
#  'Related',
#  'Killed driver pass',
#  'Speeding',
#  'Ran Red Light or Stop Sign',
#  'DL Status incident',
#  'Suspected Impairment',
#  'Restraint type',
#  'Type of road',
#  'Failure to stop and render aid',
#  'X coord',
#  'Y coord',
#  'Homeless']

# %%
# Now to update the column names in the dataset to make working with the dataset easier

new_column_list = ('type', 'crash_number', 'number_of_fatalities', 'case_number', 'location', 'area', 'date', 'month', 'day', 'hour', 'time', 'related', 'occupant_killed', 'speeding', 'red_light_stop', 'dl_status', 'suspected_impairment', 'restraint_type', 'type_of_road', 'failure_to_stop_aid', 'latitude', 'longitude', 'homeless')
df_austin_traffic.columns = new_column_list

# %%
# Now to check to see if new column names were updated in the dataframe

df_austin_traffic.columns.tolist()
# Out:
# ['type',
#  'crash_number',
#  'number_of_fatalities',
#  'case_number',
#  'location',
#  'area',
#  'date',
#  'month',
#  'day',
#  'hour',
#  'time',
#  'related',
#  'occupant_killed',
#  'speeding',
#  'red_light_stop',
#  'dl_status',
#  'suspected_impairment',
#  'restraint_type',
#  'type_of_road',
#  'failure_to_stop_aid',
#  'latitude',
#  'longitude',
#  'homeless']

# %%
# Now to visualize Austin traffic fatality data
# Austin, TX latitude and longitude values

austin_latitude = 30.27
austin_longitude = -97.74

# %%
austin_map= folium.Map(location=[austin_latitude,austin_longitude], zoom_start=12)
austin_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f6a5acbc06684b09bf330cb1b7f33a4c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f6a5acbc06684b09bf330cb1b7f33a4c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f6a5acbc06684b09bf330cb1b7f33a4c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f6a5acbc06684b09bf330cb1b7f33a4c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B30.27%2C%20-97.74%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Add locations of the traffic fatalities onto the map with markers that contain popup feature that labels 
# the type of fatality (Pedestrian, Motor Vehicle, etc.)

from folium import plugins

austin_map = folium.Map(location = [austin_latitude, austin_longitude], zoom_start = 12)

# This will group the markers into different clusters
type = plugins.MarkerCluster().add_to(austin_map)

# Loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(df_austin_traffic.longitude, df_austin_traffic.latitude, df_austin_traffic.type):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(type)

austin_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4a007a0b039247bd86c2a6c89f3bae07%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4a007a0b039247bd86c2a6c89f3bae07%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %% [markdown]
# ## Now to try the Chicago Dataset

# %% [markdown]
# ### Chicago Dataset found at https://data.cityofchicago.org/Public-Safety/Crimes-One-year-prior-to-present/x2n5-8w5q

# %% [markdown]
# ## Visualizing Police Incidents in Chicago, IL

# %%
# Import the dataset for Chicago
# Note: For the purposes of this project in order to visualize the map, rows where the latitude and longitude values were NaN 
# were deleted

df_chicago_incidents = pd.read_csv(r'C:\Users\jksmi\Downloads\Folium Project - Crime Incident (SanFran and Chicago)\crimes_one_year_prior_to_present_clean.csv')
df_chicago_incidents
# Out:
#        date_of_occurrence case_number                    block  iucr  \
# 0         9/29/2021 23:52    JE392324  003XX S SACRAMENTO BLVD  1320
# 1         9/29/2021 23:50    JE392344        026XX W CERMAK RD   320
# 2         9/29/2021 23:48    JE392074        110XX S BISHOP ST   110
# 3         9/29/2021 23:40    JE392296       041XX S WABASH AVE   560
# 4         9/29/2021 23:36    JE392303          009XX W 70TH ST  2024
# ...                   ...         ...                      ...   ...
# 200083     9/30/2020 6:00    JD384948      010XX S ASHLAND AVE  1581
# 200084     9/30/2020 6:00    JD407205      067XX S CORNELL AVE  1110
# 200085     9/30/2020 5:50    JD383827   070XX S DORCHESTER AVE   810
# 200086     9/30/2020 5:30    JD387309        027XX S DRAKE AVE   910
# 200087     9/30/2020 5:05    JD383825       003XX S CICERO AVE   860
#
#         primary_description  \
# 0           CRIMINAL DAMAGE
# 1                   ROBBERY
# 2                  HOMICIDE
# 3                   ASSAULT
# 4                 NARCOTICS
# ...                     ...
# 200083          SEX OFFENSE
# 200084   DECEPTIVE PRACTICE
# 200085                THEFT
# 200086  MOTOR VEHICLE THEFT
# 200087                THEFT
#
#                                     secondary_description  \
# 0                                              TO VEHICLE
# 1                                  STRONG ARM - NO WEAPON
# 2                                     FIRST DEGREE MURDER
# 3                                                  SIMPLE
# 4                                POSSESS - HEROIN (WHITE)
# ...                                                   ...
# 200083  NON-CONSENSUAL DISSEMINATION OF PRIVATE SEXUAL...
# 200084                                        BOGUS CHECK
# 200085                                          OVER $500
# 200086                                         AUTOMOBILE
# 200087                                       RETAIL THEFT
#
#        location_description arrest domestic  beat  ward fbi_cd  x_coordinate  \
# 0               GAS STATION      N        Y  1124  28.0     14       1156434
# 1                    STREET      N        N  1023  24.0      3       1159207
# 2                     ALLEY      N        N  2234  34.0    01A       1168527
# 3                    STREET      N        N   213   3.0    08A       1177405
# 4                    STREET      Y        N   733   6.0     18       1171431
# ...                     ...    ...      ...   ...   ...    ...           ...
# 200083            APARTMENT      N        N  1231  28.0     17       1165888
# 200084            APARTMENT      N        N   332   5.0     11       1188363
# 200085            APARTMENT      N        Y   321   5.0      6       1186752
# 200086               STREET      N        N  1032  22.0      7       1153145
# 200087          GAS STATION      Y        N  1533  28.0      6       1144438
#
#         y_coordinate   latitude  longitude                       location
# 0            1898301  41.876720 -87.701088  (41.876720197, -87.701088107)
# 1            1889299  41.851961 -87.691154  (41.851961298, -87.691153739)
# 2            1831333  41.692699 -87.658616  (41.692698911, -87.658615989)
# 3            1877502  41.819197 -87.624720   (41.81919655, -87.624719873)
# 4            1858425  41.766980 -87.647193  (41.766980264, -87.647193248)
# ...              ...        ...        ...                            ...
# 200083       1895568  41.869024 -87.666454   (41.86902427, -87.666453984)
# 200084       1860651  41.772701 -87.585060  (41.772701185, -87.585060362)
# 200085       1858681  41.767334 -87.591028  (41.767333643, -87.591028093)
# 200086       1885563  41.841832 -87.713502  (41.841831511, -87.713501996)
# 200087       1898165  41.876581 -87.745138  (41.876581037, -87.745137513)
#
# [200088 rows x 17 columns]

# %%
# Listing the columns in the dataframe

df_chicago_incidents.columns.tolist()
# Out:
# ['date_of_occurrence',
#  'case_number',
#  'block',
#  'iucr',
#  'primary_description',
#  'secondary_description',
#  'location_description',
#  'arrest',
#  'domestic',
#  'beat',
#  'ward',
#  'fbi_cd',
#  'x_coordinate',
#  'y_coordinate',
#  'latitude',
#  'longitude',
#  'location']

# %%
# Checking to see the shape of the dataframe

df_chicago_incidents.shape
# Out:
# (200088, 17)

# %%
# Again reducing the dataframe to 100 crimes due to the dataframe containing 200088 rows
# Pulling only the 1st 100 crimes in the df_chicago_incidents dataframe

limit = 100
df_chicago_incidents = df_chicago_incidents.iloc[0:limit, :]

# %%
# Confirm that dataframe has been reduced

df_chicago_incidents.shape
# Out:
# (100, 17)

# %%
# Now to visualize Chicago and where these crimes took place
# Chicago latitude and longitude values

chi_latitude = 41.88
chi_longitude = -87.63

# %%
# Create map and display it

chicago_map = folium.Map(location=[chi_latitude, chi_longitude], zoom_start=12)
chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_18aab74957da4c9fa17935e69da8a492%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_18aab74957da4c9fa17935e69da8a492%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_18aab74957da4c9fa17935e69da8a492%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_18aab74957da4c9fa17935e69da8a492%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B41.88%2C%20-87.63%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Add locations of the crimes onto the map with markers that contain popup feature that labels the primary_description

crime_locations = folium.map.FeatureGroup()

for lat, lng, in zip(df_chicago_incidents.longitude, df_chicago_incidents.latitude):
    crime_locations.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

latitudes = list(df_chicago_incidents.latitude)
longitudes = list(df_chicago_incidents.longitude)
labels = list(df_chicago_incidents.primary_description)

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(chicago_map)
    
chicago_map.add_child(crime_locations)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_faec3c0aaef14c40bdadedad865eb8be%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_faec3c0aaef14c40bdadedad865eb8be%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %% [markdown]
# ### Project Complete

# %% [markdown]
# ### Inspiration Credit - Alex Aklson
